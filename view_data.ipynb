# %%
import pandas as pd
df = pd.read_csv("comments-3.txt")

# %%
df
# Out:
#                                            results text
# 0     __label__perfective MAHOUT-1045: committing pa...
# 1     __label__perfective Add notes for coptic bug f...
# 2     __label__corrective cloudStack 3.0 new UI - Na...
# 3     __label__corrective "add logic to handle all 2...
# 4     __label__corrective Fixed adding route for add...
# 5     __label__unknown [SMALLFIX] Fix the duplicated...
# 6     __label__perfective Improved performance on ma...
# 7       __label__adaptive Add AppSales to featured list
# 8     __label__perfective Improve performance of New...
# 9     __label__corrective suffice to pick up remotin...
# 10      __label__perfective Improve logging readability
# 11    __label__corrective [Automation] - Fix test fa...
# 12    __label__perfective Some modest improvements t...
# 13    __label__corrective fix issue 1992 - ensure th...
# 14    __label__adaptive no need now to get version f...
# 15    __label__corrective "new UI - template page  I...
# ...
